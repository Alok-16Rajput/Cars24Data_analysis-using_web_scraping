# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Base URL with a placeholder for the page number
base_url = 'https://www.cars24.com/buy-used-car?f=make%3A%3D%3Akia&sort=bestmatch&serveWarrantyCount=true&listingSource=Search_LP&storeCityId=2378'


# Function to fetch car details from a single page
def fetch_page(page_number):
    url = base_url.format(page_number)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    results = soup.find_all('div', {'class': '_7jb8Q _1Ey60'})  # Adjust this selector based on actual HTML
    cars = []
    for result in results:
        car_details = {}
        try:
            car_details['Title'] = result.find('h3').get_text(strip=True)
        except AttributeError:
            car_details['Title'] = None
        try:
            car_details['Details'] = result.find('ul', {'class': '_3jRcd'}).get_text(strip=True)
        except AttributeError:
            car_details['Price'] = None
        try:
            car_details['Price'] = result.find('strong', {'class': '_37WXy'}).get_text(strip=True)
        except AttributeError:
            car_details['Location'] = None
        try:
            car_details['Location'] = result.find('p', {'class': '_2rxhF'}).get_text(strip=True)
        except AttributeError:
            car_details['Location'] = None
        cars.append(car_details)
    return cars

# Fetch car details from multiple pages
all_cars = []
for page_number in range(1, 6):  # Adjust range as needed
    page_cars = fetch_page(page_number)
    all_cars.extend(page_cars)

# Convert the list of cars to a DataFrame
df = pd.DataFrame(all_cars)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                             Title                                Details  \
# 0      2022 KIA SELTOSGTX (O) 1.4  Reg. serviced23,252 kmPetrol1st owner
# 1  2020 KIA SONETGTX PLUS 1.0 IMT        Sunroof35,415 kmPetrol1st owner
# 2      2022 KIA SONETGTX PLUS 1.5  Reg. serviced28,326 kmDiesel1st owner
# 3     2020 KIA SELTOSHTK PLUS 1.5   Alloy wheels48,880 kmPetrol1st owner
# 4     2020 KIA SELTOSHTK PLUS 1.5   Alloy wheels15,160 kmPetrol1st owner
#
#      Price                                      Location
# 0  ₹14.60L     Free Test DriveTomorrowatGoregaon, Mumbai
# 1   ₹9.94L     Free Test DriveTomorrowatGoregaon, Mumbai
# 2  ₹11.99L     Free Test DriveTomorrowatGoregaon, Mumbai
# 3   ₹9.90L  Free Test DriveTomorrowatMulund West, Mumbai
# 4  ₹10.79L     Free Test DriveTomorrowatGoregaon, Mumbai

# %%
df.shape
# Out:
# (50, 4)

# %%
Kia_cars = df[df['Title'].str.contains('KIA', case=False, na=False)]

# Display the filtered DataFrame
print(Kia_cars.head())
# Out:
#                             Title                                Details  \
# 0      2022 KIA SELTOSGTX (O) 1.4  Reg. serviced23,252 kmPetrol1st owner
# 1  2020 KIA SONETGTX PLUS 1.0 IMT        Sunroof35,415 kmPetrol1st owner
# 2      2022 KIA SONETGTX PLUS 1.5  Reg. serviced28,326 kmDiesel1st owner
# 3     2020 KIA SELTOSHTK PLUS 1.5   Alloy wheels48,880 kmPetrol1st owner
# 4     2020 KIA SELTOSHTK PLUS 1.5   Alloy wheels15,160 kmPetrol1st owner
#
#      Price                                      Location
# 0  ₹14.60L     Free Test DriveTomorrowatGoregaon, Mumbai
# 1   ₹9.94L     Free Test DriveTomorrowatGoregaon, Mumbai
# 2  ₹11.99L     Free Test DriveTomorrowatGoregaon, Mumbai
# 3   ₹9.90L  Free Test DriveTomorrowatMulund West, Mumbai
# 4  ₹10.79L     Free Test DriveTomorrowatGoregaon, Mumbai

# %%
Kia_cars.to_csv('Kia_cars.csv', index=False)

# Optionally, display a message confirming that the file has been saved
print("Kia cars data has been saved to 'Kia_cars.csv'.")
# Out:
# Kia cars data has been saved to 'Kia_cars.csv'.

# %%
df = pd.read_csv('Kia_cars.csv')
df
# Out:
#                                      Title  \
# 0               2022 KIA SELTOSGTX (O) 1.4
# 1           2020 KIA SONETGTX PLUS 1.0 IMT
# 2               2022 KIA SONETGTX PLUS 1.5
# 3              2020 KIA SELTOSHTK PLUS 1.5
# 4              2020 KIA SELTOSHTK PLUS 1.5
# 5     2020 KIA SELTOSHTX PLUS AT1.5 DIESEL
# 6   2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 7   2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 8   2021 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 9           2020 KIA SONETHTX PLUS 1.0 IMT
# 10              2022 KIA SELTOSGTX (O) 1.4
# 11          2020 KIA SONETGTX PLUS 1.0 IMT
# 12              2022 KIA SONETGTX PLUS 1.5
# 13             2020 KIA SELTOSHTK PLUS 1.5
# 14             2020 KIA SELTOSHTK PLUS 1.5
# 15    2020 KIA SELTOSHTX PLUS AT1.5 DIESEL
# 16  2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 17  2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 18  2021 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 19          2020 KIA SONETHTX PLUS 1.0 IMT
# 20              2022 KIA SELTOSGTX (O) 1.4
# 21          2020 KIA SONETGTX PLUS 1.0 IMT
# 22              2022 KIA SONETGTX PLUS 1.5
# 23             2020 KIA SELTOSHTK PLUS 1.5
# 24             2020 KIA SELTOSHTK PLUS 1.5
# 25    2020 KIA SELTOSHTX PLUS AT1.5 DIESEL
# 26  2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 27  2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 28  2021 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 29          2020 KIA SONETHTX PLUS 1.0 IMT
# 30              2022 KIA SELTOSGTX (O) 1.4
# 31          2020 KIA SONETGTX PLUS 1.0 IMT
# 32              2022 KIA SONETGTX PLUS 1.5
# 33             2020 KIA SELTOSHTK PLUS 1.5
# 34             2020 KIA SELTOSHTK PLUS 1.5
# 35    2020 KIA SELTOSHTX PLUS AT1.5 DIESEL
# 36  2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 37  2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 38  2021 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 39          2020 KIA SONETHTX PLUS 1.0 IMT
# 40              2022 KIA SELTOSGTX (O) 1.4
# 41          2020 KIA SONETGTX PLUS 1.0 IMT
# 42              2022 KIA SONETGTX PLUS 1.5
# 43             2020 KIA SELTOSHTK PLUS 1.5
# 44             2020 KIA SELTOSHTK PLUS 1.5
# 45    2020 KIA SELTOSHTX PLUS AT1.5 DIESEL
# 46  2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 47  2020 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 48  2021 KIA SELTOSGTX PLUS DCT 1.4 PETROL
# 49          2020 KIA SONETHTX PLUS 1.0 IMT
#
#                                   Details    Price  \
# 0   Reg. serviced23,252 kmPetrol1st owner  ₹14.60L
# 1         Sunroof35,415 kmPetrol1st owner   ₹9.94L
# 2   Reg. serviced28,326 kmDiesel1st owner  ₹11.99L
# 3    Alloy wheels48,880 kmPetrol1st owner   ₹9.90L
# 4    Alloy wheels15,160 kmPetrol1st owner  ₹10.79L
# 5       Top Model45,979 kmDiesel1st owner  ₹13.79L
# 6         Sunroof65,200 kmPetrol1st owner  ₹13.21L
# 7         Sunroof35,055 kmPetrol1st owner  ₹14.44L
# 8         Sunroof33,374 kmPetrol2nd owner  ₹14.13L
# 9         Sunroof36,460 kmPetrol1st owner   ₹9.95L
# 10  Reg. serviced23,252 kmPetrol1st owner  ₹14.60L
# 11        Sunroof35,415 kmPetrol1st owner   ₹9.94L
# 12  Reg. serviced28,326 kmDiesel1st owner  ₹11.99L
# 13   Alloy wheels48,880 kmPetrol1st owner   ₹9.90L
# 14   Alloy wheels15,160 kmPetrol1st owner  ₹10.79L
# 15      Top Model45,979 kmDiesel1st owner  ₹13.79L
# 16        Sunroof65,200 kmPetrol1st owner  ₹13.21L
# 17        Sunroof35,055 kmPetrol1st owner  ₹14.44L
# 18        Sunroof33,374 kmPetrol2nd owner  ₹14.13L
# 19        Sunroof36,460 kmPetrol1st owner   ₹9.95L
# 20  Reg. serviced23,252 kmPetrol1st owner  ₹14.60L
# 21        Sunroof35,415 kmPetrol1st owner   ₹9.94L
# 22  Reg. serviced28,326 kmDiesel1st owner  ₹11.99L
# 23   Alloy wheels48,880 kmPetrol1st owner   ₹9.90L
# 24   Alloy wheels15,160 kmPetrol1st owner  ₹10.79L
# 25      Top Model45,979 kmDiesel1st owner  ₹13.79L
# 26        Sunroof65,200 kmPetrol1st owner  ₹13.21L
# 27        Sunroof35,055 kmPetrol1st owner  ₹14.44L
# 28        Sunroof33,374 kmPetrol2nd owner  ₹14.13L
# 29        Sunroof36,460 kmPetrol1st owner   ₹9.95L
# 30  Reg. serviced23,252 kmPetrol1st owner  ₹14.60L
# 31        Sunroof35,415 kmPetrol1st owner   ₹9.94L
# 32  Reg. serviced28,326 kmDiesel1st owner  ₹11.99L
# 33   Alloy wheels48,880 kmPetrol1st owner   ₹9.90L
# 34   Alloy wheels15,160 kmPetrol1st owner  ₹10.79L
# 35      Top Model45,979 kmDiesel1st owner  ₹13.79L
# 36        Sunroof65,200 kmPetrol1st owner  ₹13.21L
# 37        Sunroof35,055 kmPetrol1st owner  ₹14.44L
# 38        Sunroof33,374 kmPetrol2nd owner  ₹14.13L
# 39        Sunroof36,460 kmPetrol1st owner   ₹9.95L
# 40  Reg. serviced23,252 kmPetrol1st owner  ₹14.60L
# 41        Sunroof35,415 kmPetrol1st owner   ₹9.94L
# 42  Reg. serviced28,326 kmDiesel1st owner  ₹11.99L
# 43   Alloy wheels48,880 kmPetrol1st owner   ₹9.90L
# 44   Alloy wheels15,160 kmPetrol1st owner  ₹10.79L
# 45      Top Model45,979 kmDiesel1st owner  ₹13.79L
# 46        Sunroof65,200 kmPetrol1st owner  ₹13.21L
# 47        Sunroof35,055 kmPetrol1st owner  ₹14.44L
# 48        Sunroof33,374 kmPetrol2nd owner  ₹14.13L
# 49        Sunroof36,460 kmPetrol1st owner   ₹9.95L
#
#                                         Location
# 0      Free Test DriveTomorrowatGoregaon, Mumbai
# 1      Free Test DriveTomorrowatGoregaon, Mumbai
# 2      Free Test DriveTomorrowatGoregaon, Mumbai
# 3   Free Test DriveTomorrowatMulund West, Mumbai
# 4      Free Test DriveTomorrowatGoregaon, Mumbai
# 5      Free Test DriveTomorrowatGoregaon, Mumbai
# 6   Free Test DriveTomorrowatMulund West, Mumbai
# 7      Free Test DriveTomorrowatGoregaon, Mumbai
# 8      Free Test DriveTomorrowatGoregaon, Mumbai
# 9      Free Test DriveTomorrowatGoregaon, Mumbai
# 10     Free Test DriveTomorrowatGoregaon, Mumbai
# 11     Free Test DriveTomorrowatGoregaon, Mumbai
# 12     Free Test DriveTomorrowatGoregaon, Mumbai
# 13  Free Test DriveTomorrowatMulund West, Mumbai
# 14     Free Test DriveTomorrowatGoregaon, Mumbai
# 15     Free Test DriveTomorrowatGoregaon, Mumbai
# 16  Free Test DriveTomorrowatMulund West, Mumbai
# 17     Free Test DriveTomorrowatGoregaon, Mumbai
# 18     Free Test DriveTomorrowatGoregaon, Mumbai
# 19     Free Test DriveTomorrowatGoregaon, Mumbai
# 20     Free Test DriveTomorrowatGoregaon, Mumbai
# 21     Free Test DriveTomorrowatGoregaon, Mumbai
# 22     Free Test DriveTomorrowatGoregaon, Mumbai
# 23  Free Test DriveTomorrowatMulund West, Mumbai
# 24     Free Test DriveTomorrowatGoregaon, Mumbai
# 25     Free Test DriveTomorrowatGoregaon, Mumbai
# 26  Free Test DriveTomorrowatMulund West, Mumbai
# 27     Free Test DriveTomorrowatGoregaon, Mumbai
# 28     Free Test DriveTomorrowatGoregaon, Mumbai
# 29     Free Test DriveTomorrowatGoregaon, Mumbai
# 30     Free Test DriveTomorrowatGoregaon, Mumbai
# 31     Free Test DriveTomorrowatGoregaon, Mumbai
# 32     Free Test DriveTomorrowatGoregaon, Mumbai
# 33  Free Test DriveTomorrowatMulund West, Mumbai
# 34     Free Test DriveTomorrowatGoregaon, Mumbai
# 35     Free Test DriveTomorrowatGoregaon, Mumbai
# 36  Free Test DriveTomorrowatMulund West, Mumbai
# 37     Free Test DriveTomorrowatGoregaon, Mumbai
# 38     Free Test DriveTomorrowatGoregaon, Mumbai
# 39     Free Test DriveTomorrowatGoregaon, Mumbai
# 40     Free Test DriveTomorrowatGoregaon, Mumbai
# 41     Free Test DriveTomorrowatGoregaon, Mumbai
# 42     Free Test DriveTomorrowatGoregaon, Mumbai
# 43  Free Test DriveTomorrowatMulund West, Mumbai
# 44     Free Test DriveTomorrowatGoregaon, Mumbai
# 45     Free Test DriveTomorrowatGoregaon, Mumbai
# 46  Free Test DriveTomorrowatMulund West, Mumbai
# 47     Free Test DriveTomorrowatGoregaon, Mumbai
# 48     Free Test DriveTomorrowatGoregaon, Mumbai
# 49     Free Test DriveTomorrowatGoregaon, Mumbai

# %%
df.head(10)

import pandas as pd

# Define the path to your CSV file
file_path = 'Kia_cars.csv'

# Define the columns to use
cols = ['Title', 'Details', 'Price', 'Location']

# Function to process each chunk
def process_chunk(chunk):
    # Extract Year of Manufacture (from Title)
    chunk['Year'] = chunk['Title'].str.extract(r'(\d{4})')

    # Extract Kilometers Driven
    chunk['Kilometers Driven'] = chunk['Details'].str.extract(r'(\d{1,3}(?:,\d{3})*)\s*km')

    # Extract Fuel Type
    chunk['Fuel Type'] = chunk['Details'].str.extract(r'(Petrol|Diesel)')

    # Extract Owner
    chunk['Owner'] = chunk['Details'].str.extract(r'(\d{1,2}st owner|1st owner|2nd owner|3rd owner)')

    # Remove the Year from the 'Title' column and rename it to 'Name'
    chunk['Title'] = chunk['Title'].str.replace(r'^\d{4}\s*', '', regex=True).str.strip()
    chunk.rename(columns={'Title': 'Name'}, inplace=True)

    return chunk

# Initialize an empty list to hold processed chunks
processed_chunks = []

# Process the CSV file in chunks
for chunk in pd.read_csv(file_path, usecols=cols, chunksize=10000):
    processed_chunk = process_chunk(chunk)
    processed_chunks.append(processed_chunk)

# Concatenate all chunks into a single DataFrame
final_df = pd.concat(processed_chunks, ignore_index=True)

# Save the final DataFrame to a CSV file
final_df.to_csv('Kia_cars_data.csv', index=False)

print("Data processing complete and saved to 'Kia_cars_data.csv'.")
# Out:
# Data processing complete and saved to 'Kia_cars_data.csv'.
